# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import numpy as np
import pandas as pd

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
temp=pd.read_csv(r"C:\Users\Michel\git2\LabsDataAnalyticsIronhack\module_2\Lab_10_Subsetting_and_Descriptive_Statistics\Temp_States.csv")

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# City and State are object and Temp is a float which is normal

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
temp[temp['State']=='New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
temp[temp['State']=='New York'].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
temp[temp['Temperature']>15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
temp['City'][temp['Temperature']>15]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
temp['City'][(temp['Temperature']>15) & (temp['Temperature']<20)]
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
temp.groupby('State').agg('mean')
# Out:
#              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741

# %%
temp.groupby('State').agg('std')
# Out:
#              Temperature
# State
# Connecticut     1.964186
# New Jersey      1.571348
# New York        8.133404

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
employees=pd.read_csv(r"C:\Users\Michel\git2\LabsDataAnalyticsIronhack\module_2\Lab_10_Subsetting_and_Descriptive_Statistics\employees.csv")

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
your comments here
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employees.describe()
# Out:
#             Years      Salary
# count  500.000000  500.000000
# mean     7.556000   73.528000
# std      4.465731   26.890061
# min      1.000000   30.000000
# 25%      3.000000   50.000000
# 50%      7.000000   72.000000
# 75%     11.250000   97.000000
# max     15.000000  120.000000

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
employees[employees['Salary']==min(employees['Salary'])]
# Out:
#     Department Education      Title      Name  Years  Salary
# 27          IT  Bachelor    Analyst      Sean     12      30
# 106      Admin  Bachelor  associate      Luke      4      30
# 128      Sales       PhD         VP      Adam      8      30
# 139      Sales       PhD    Analyst      Rick     11      30
# 214      Sales    Master         VP      Neil     11      30
# 266         HR       PhD  associate    Marcel     10      30
# 452         IT  Bachelor    Analyst  Augustin     13      30

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees[employees['Name']=='David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees[employees['Name']=='David']['Salary']
# Out:
# 0      58
# 124    31
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
employees[employees['Title']=='associate']
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
temp.head(3)
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %%
# Method 2
# your code here
temp.loc[0:2,:]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
employees[(employees['Title']=='associate') & (employees['Salary']>55) ]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees.groupby('Years').mean()
# Out:
#           Salary
# Years
# 1      75.863636
# 2      75.857143
# 3      74.571429
# 4      77.129032
# 5      73.857143
# 6      72.382353
# 7      73.840000
# 8      64.250000
# 9      76.741935
# 10     73.351351
# 11     74.866667
# 12     73.454545
# 13     71.935484
# 14     70.968750
# 15     69.758621

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees.groupby('Title').mean()
# Out:
#               Years     Salary
# Title
# Analyst    7.849162  73.703911
# VP         7.619632  72.907975
# associate  7.158228  73.968354

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
employees.describe()
# Out:
#             Years      Salary
# count  500.000000  500.000000
# mean     7.556000   73.528000
# std      4.465731   26.890061
# min      1.000000   30.000000
# 25%      3.000000   50.000000
# 50%      7.000000   72.000000
# 75%     11.250000   97.000000
# max     15.000000  120.000000

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here
employees.groupby('Department').mean()
# Out:
#                Years     Salary
# Department
# Admin       7.642276  76.325203
# HR          7.172131  74.237705
# IT          8.141791  70.671642
# Sales       7.206612  73.132231

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
employees.groupby('Department').describe()
# Out:
#             Years                                                 Salary  \
#             count      mean       std  min   25%  50%   75%   max  count
# Department
# Admin       123.0  7.642276  4.706344  1.0  3.00  8.0  12.0  15.0  123.0
# HR          122.0  7.172131  4.292397  1.0  3.25  6.0  11.0  15.0  122.0
# IT          134.0  8.141791  4.472393  1.0  4.00  8.5  12.0  15.0  134.0
# Sales       121.0  7.206612  4.358741  1.0  3.00  7.0  11.0  15.0  121.0
#
#
#                  mean        std   min    25%   50%    75%    max
# Department
# Admin       76.325203  25.734615  30.0  53.50  78.0  98.00  120.0
# HR          74.237705  26.522423  30.0  50.25  74.5  96.00  119.0
# IT          70.671642  27.406101  30.0  46.25  69.0  97.75  120.0
# Sales       73.132231  27.819340  30.0  49.00  69.0  95.00  120.0

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders=pd.read_csv(r"C:\Users\Michel\git2\LabsDataAnalyticsIronhack\module_2\Lab_10_Subsetting_and_Descriptive_Statistics\orders.csv", sep=";")
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 8:26:00
# 1                  white metal lantern         6  2010-12-01 8:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 8:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 8:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 8:26:00
#
#   UnitPrice  CustomerID         Country amount_spent
# 0      2,55       17850  United Kingdom         15,3
# 1      3,39       17850  United Kingdom        20,34
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  object
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  object
# dtypes: int64(8), object(6)
# memory usage: 42.5+ MB

# %%
orders.replace(",",".",regex=True,inplace=True)

# %%
orders['amount_spent']=orders['amount_spent'].astype(float, errors = 'raise')

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity     CustomerID  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823   15294.315171
# std         1.928274       2.273535     180.420210    1713.169877
# min         1.000000       6.000000       1.000000   12346.000000
# ...

# %%
"""
your comments here
"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
22.39

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
168469 and 0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
orders[orders['Country']=='Spain']['CustomerID'].unique()
# Out:
# array([12557, 17097, 12540, 12551, 12484, 12539, 12510, 12421, 12502,
#        12462, 12507, 12541, 12547, 12597, 12545, 12596, 12354, 12417,
#        12455, 12450, 12548, 12556, 12550, 12546, 12454, 12448, 12544,
#        12538, 12445, 12442], dtype=int64)

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
len(orders[orders['Country']=='Spain']['CustomerID'].unique())
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
order=orders[['CustomerID','Quantity']].groupby('CustomerID').agg('sum')
order[order['Quantity']>50]
# Out:
#             Quantity
# CustomerID
# 12346          74215
# 12347           2458
# 12348           2341
# 12349            631
# 12350            197
# ...              ...
# 18278             66
# 18281             54
# 18282            103
# 18283           1397
# 18287           1586
#
# [4091 rows x 1 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
orders[orders['Quantity']>50]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 397720      541702     581566     23404  2011     12    5    11
# 397721      541703     581567     21417  2011     12    5    11
# 397729      541711     581567     21326  2011     12    5    11
# 397761      541746     581571     23167  2011     12    5    12
# 397882      541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46          paper chain kit 50's christmas        80   2010-12-01 9:00:00
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
orders[orders['amount_spent']==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
orders[orders['Description'].str.startswith("lunch bag")]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate UnitPrice  \
# 93          lunch bag red retrospot        10   2010-12-01 9:37:00      1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
orders[orders['Description'].str.startswith("lunch bag")][orders['year']==2011]
# Out:
# <ipython-input-125-04fb05d7f3fb>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   orders[orders['Description'].str.startswith("lunch bag")][orders['year']==2011]
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
orders[orders['Country']=='Spain'].groupby('amount_spent').size()
# Out:
# amount_spent
# 0.00       1
# 0.21       3
# 0.29       1
# 0.39       3
# 0.42       1
#           ..
# 417.50     1
# 488.16     2
# 1080.00    1
# 1220.40    2
# 1350.00    3
# Length: 309, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
orders[orders['month']==8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475          6 ribbons elegant christmas        96   2011-08-01 8:30:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
orders[orders['month']==8].groupby('Country').size()
# Out:
# Country
# Australia            107
# Austria               88
# Belgium              194
# Canada                 5
# Channel Islands      140
# Denmark               16
# EIRE                 593
# Finland               61
# France               569
# Germany              795
# Iceland               22
# Israel               171
# Italy                 95
# Malta                 55
# Netherlands          280
# Norway                77
# Poland                17
# Portugal              41
# Spain                252
# Sweden                40
# Switzerland          267
# United Kingdom     23105
# Unspecified           23
# dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders.groupby('Country').mean()
# Out:
#                          Unnamed: 0      InvoiceNo         year      month  \
# Country
# Australia             224857.287764  556217.951055  2010.972996   6.062447
# Austria               297239.085427  562367.633166  2010.979899   7.623116
# Bahrain               184964.000000  552790.411765  2011.000000   5.000000
# Belgium               276657.968981  560543.014279  2010.953225   7.404727
# Brazil                157314.500000  550201.000000  2011.000000   4.000000
# Canada                240605.867550  557964.476821  2011.000000   6.377483
# Channel Islands       255107.524064  558786.728610  2010.977273   6.791444
# Cyprus                236759.193811  556821.771987  2010.864821   7.311075
# Czech Republic        215563.200000  555053.600000  2011.000000   5.200000
# Denmark               299546.760526  562479.600000  2010.947368   7.905263
# EIRE                  289810.162476  561673.445012  2010.953855   7.726996
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
orders[orders['UnitPrice']==orders['UnitPrice'].max()]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 335008      455261     575607       DOT  2011     11    4    12
#
#            Description  Quantity          InvoiceDate UnitPrice  CustomerID  \
# 335008  dotcom postage         1  2011-11-10 12:37:00    908.16       14096
#
#                Country  amount_spent
# 335008  United Kingdom        908.16

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders.groupby('year').mean()
# Out:
#          Unnamed: 0      InvoiceNo      month       day       hour   Quantity  \
# year
# 2010   19884.040482  538009.305122  12.000000  3.745528  12.897630  11.937309
# 2011  296660.861310  562207.976246   7.303803  3.605338  12.716328  13.098138
#
#         CustomerID  amount_spent
# year
# 2010  15529.088417     21.892733
# 2011  15277.794830     22.430074
