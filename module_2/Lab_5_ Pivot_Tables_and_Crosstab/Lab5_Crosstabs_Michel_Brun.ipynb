# %%
# Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
df= pd.read_csv(r'C:\Users\Michel\Downloads\movie_metadata.csv')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
pd.crosstab(data['country'], data['director_name'], margins=True, margins_name='Total')[['Total']]
# Out:
# director_name         Total
# country
# Afghanistan               1
# Argentina                 4
# Aruba                     1
# Australia                53
# Bahamas                   1
# ...                     ...
# UK                      434
# USA                    3733
# United Arab Emirates      1
# West Germany              3
# Total                  4936
#
# [66 rows x 1 columns]

# %% [markdown]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %%
pd.crosstab([data['director_name'],data['genres']],data['country'],margins='Total')
# Out:
# country                                                    Afghanistan  \
# director_name      genres
# A. Raven Cruz      Action|Adventure|Comedy|Fantasy|Sci-Fi            0
# Aaron Hann         Drama|Horror|Mystery|Sci-Fi|Thriller              0
# Aaron Schneider    Drama|Mystery                                     0
# Aaron Seltzer      Comedy|Romance                                    0
# Abel Ferrara       Crime|Drama                                       0
# ...                                                                ...
# Álex de la Iglesia Crime|Mystery|Thriller                            0
# Émile Gaudreault   Comedy|Drama                                      0
# Éric Tessier       Action|Drama|Horror|Thriller                      0
# Étienne Faure      Drama|Musical|Romance                             0
# All                                                                  1
#
# country                                                    Argentina  Aruba  \
# ...

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %%
pd.crosstab(data['genres'],data['color'],values=data.duration,aggfunc='mean',margins=True,margins_name='Total')
# Out:
# color                                                Black and White  \
# genres
# Action                                                    111.000000
# Action|Adventure                                                 NaN
# Action|Adventure|Animation|Comedy|Crime|Family|...               NaN
# Action|Adventure|Animation|Comedy|Drama|Family|...               NaN
# Action|Adventure|Animation|Comedy|Family                         NaN
# ...                                                              ...
# Thriller                                                         NaN
# Thriller|War                                              133.000000
# Thriller|Western                                           85.000000
# Western                                                          NaN
# Total                                                     112.253589
#
# color                                                    Color       Total
# genres
# ...

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)

# %%
data['film_likes']= data['actor_1_facebook_likes'] + data['actor_2_facebook_likes'] + data['actor_3_facebook_likes']

# %%
likes=pd.crosstab(data.director_name, data.film_likes, values=data['film_likes'], aggfunc='sum', margins=True,  margins_name="Total" )
likes[['Total']]
# Out:
# film_likes               Total
# director_name
# A. Raven Cruz           1094.0
# Aaron Hann               406.0
# Aaron Schneider        16970.0
# Aaron Seltzer           4598.0
# Abel Ferrara            2198.0
# ...                        ...
# Álex de la Iglesia       702.0
# Émile Gaudreault         917.0
# Éric Tessier              72.0
# Étienne Faure             19.0
# Total               44334843.0
#
# [2386 rows x 1 columns]
