# %%
import requests
r=requests.get('https://xkcd.com/1906/')

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2678', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Mon, 06 Dec 2021 05:00:04 GMT', 'ETag': 'W/"61ad98d4-1b1c"', 'Expires': 'Mon, 06 Dec 2021 13:13:18 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 06 Dec 2021 13:12:29 GMT', 'Via': '1.1 varnish', 'Age': '250', 'X-Served-By': 'cache-cdg20761-CDG', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1638796349.153510,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
r.headers['Content-Type']
# Out:
# 'text/html; charset=UTF-8'

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Making Progress</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script>\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Making Progress">\n<meta property="og:url" content="https://xkcd.com/1906/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/making_progress_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<div id="topContainer">\n<div id="topLeft">\n<ul>\n<li><a href="/archive">Archive</a></li>\n<li><a href="https://what-if.xkcd.com">What If?</a></li>\n<li><a href="https://blag.xkcd.com">Blag</a></li>\n<li><a href="/how-to/">How To</a></li>\n<li><a href="https://store.xkcd.com/">Store</a></li>\n<li><a rel="author" href="/about">About</a></li>\n<li><a href="/atom.xml">Feed</a> &bull; <a href="/newsletter/">Email</a></li>\n<li><a href="https://twitter.com/xkcd/">TW</a> &bull; <a href="https://www.facebook.com/TheXKCD/">FB</a> &bull; <a href="https://www.instagram.com/xkcd/">IG</a></li>\n</ul>\n</div>\n<div id="topRight">\n<div id="masthead">\n<span><a href="/"><img src="/s/0b7742.png" alt="xkcd.com logo" height="83" width="185"/></a></span>\n<span id="slogan">A webcomic of romance,<br/> sarcasm, math, and language.</span>\n</div>\n<div id="news">\n<div id="xkcdBanner"><a href="https://blacklivesmatter.com/"><img border=0 src="//imgs.xkcd.com/news/blm.png"></a></div>\n\n</div>\n</div>\n<div id="bgLeft" class="bg box"></div>\n<div id="bgRight" class="bg box"></div>\n</div>\n<div id="middleContainer" class="box">\n\n<div id="ctitle">Making Progress</div>\n<ul class="comicNav">\n<li><a href="/1/">|&lt;</a></li>\n<li><a rel="prev" href="/1905/" accesskey="p">&lt; Prev</a></li>\n<li><a href="//c.xkcd.com/random/comic/">Random</a></li>\n<li><a rel="next" href="/1907/" accesskey="n">Next &gt;</a></li>\n<li><a href="/">&gt;|</a></li>\n</ul>\n<div id="comic">\n<img src="//imgs.xkcd.com/comics/making_progress.png" title="I started off with countless problems. But now I know, thanks to COUNT(), that I have &quot;#REF! ERROR: Circular dependency detected&quot; problems." alt="Making Progress" srcset="//imgs.xkcd.com/comics/making_progress_2x.png 2x" style="image-orientation:none" />\n</div>\n<ul class="comicNav">\n<li><a href="/1/">|&lt;</a></li>\n<li><a rel="prev" href="/1905/" accesskey="p">&lt; Prev</a></li>\n<li><a href="//c.xkcd.com/random/comic/">Random</a></li>\n<li><a rel="next" href="/1907/" accesskey="n">Next &gt;</a></li>\n<li><a href="/">&gt;|</a></li>\n</ul>\n<br />\nPermanent link to this comic: <a href="https://xkcd.com/1906">https://xkcd.com/1906/</a><br />\nImage URL (for hotlinking/embedding): <a href= "https://imgs.xkcd.com/comics/making_progress.png">https://imgs.xkcd.com/comics/making_progress.png</a>\n\n<div id="transcript" style="display: none"></div>\n</div>\n<div id="bottom" class="box">\n<img src="//imgs.xkcd.com/s/a899e84.jpg" width="520" height="100" alt="Selected Comics" usemap="#comicmap"/>\n<map id="comicmap" name="comicmap">\n<area shape="rect" coords="0,0,100,100" href="/150/" alt="Grownups"/>\n<area shape="rect" coords="104,0,204,100" href="/730/" alt="Circuit Diagram"/>\n<area shape="rect" coords="208,0,308,100" href="/162/" alt="Angular Momentum"/>\n<area shape="rect" coords="312,0,412,100" href="/688/" alt="Self-Description"/>\n<area shape="rect" coords="416,0,520,100" href="/556/" alt="Alternative Energy Revolution"/>\n</map>\n<br />\n<a href="//xkcd ...

# %%
receive = requests.get('https://imgs.xkcd.com/comics/meat_cereals.jpg')
with open(r'c:\Users\Michel\Downloads\imageIronhack.png','wb') as f:
    f.write(receive.content)

# %%
import requests

ploads={'things':2,'total':25}
r = requests.get('https://httpbin.org/get',params=ploads)
print(r.text)
print(r.url)
# Out:
# {
#   "args": {
#     "things": "2",
#     "total": "25"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61ae12cd-3573cd122b11c8c46b2ae138"
#   },
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/get?things=2&total=25"
# }
#
# https://httpbin.org/get?things=2&total=25

# %%
import requests
pload={'username' : 'Michel','password':'admin4'}
r = requests.post('https://httpbin.org/post',data=pload) 
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "admin4",
#     "username": "Michel"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "31",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61ae1301-41f6ff5f6b56d8407db6a6a7"
#   },
#   "json": null,
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/post"
# }

# %%
r_dictionary=r.json()
print(r.json()['form'])
# Out:
# {'password': 'admin4', 'username': 'Michel'}

# %%
receive = requests.get('https://api.github.com/repos/ta-data-par/data-ber-01-20/issues/comments')

# %%
receive = requests.get('https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/commits{/sha}')

# %%
print(receive.text)
# Out:
# {"message":"Not Found","documentation_url":"https://docs.github.com/rest"}

# %%
receive = requests.get('https://api.github.com/users/ta-data-par/repos')

# %%
print(receive)
# Out:
# <Response [200]>

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
import json
import requests

response = requests.get('https://api.github.com/users/ta-data-par/repos')
#response = requests.get('https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/commits')
response.status_code
results = response.json()

print(results)

import pandas as pd
data = pd.DataFrame(results)
data.head(10)
print()
print(data.forks.value_counts())
# Out:
# [{'id': 185275438, 'node_id': 'MDEwOlJlcG9zaXRvcnkxODUyNzU0Mzg=', 'name': 'code', 'full_name': 'ta-data-par/code', 'private': False, 'owner': {'login': 'ta-data-par', 'id': 50342645, 'node_id': 'MDQ6VXNlcjUwMzQyNjQ1', 'avatar_url': 'https://avatars.githubusercontent.com/u/50342645?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ta-data-par', 'html_url': 'https://github.com/ta-data-par', 'followers_url': 'https://api.github.com/users/ta-data-par/followers', 'following_url': 'https://api.github.com/users/ta-data-par/following{/other_user}', 'gists_url': 'https://api.github.com/users/ta-data-par/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ta-data-par/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ta-data-par/subscriptions', 'organizations_url': 'https://api.github.com/users/ta-data-par/orgs', 'repos_url': 'https://api.github.com/users/ta-data-par/repos', 'events_url': 'https://api.github.com/users/ta-data-par/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ta-data-par/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/ta-data-par/code', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ta-data-par/code', 'forks_url': 'https://api.github.com/repos/ta-data-par/code/forks', 'keys_url': 'https://api.github.com/repos/ta-data-par/code/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ta-data-par/code/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ta-data-par/code/teams', 'hooks_url': 'https://api.github.com/repos/ta-data-par/code/hooks', 'issue_events_url': 'https://api.github.com/repos/ta-data-par/code/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ta-data-par/code/events', 'assignees_url': 'https://api.github.com/repos/ta-data-par/code/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ta-data-par/code/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ta-data-par/code/tags', 'blobs_url': 'https://api.github.com/repos/ta-data-par/code/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ta-data-par/code/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ta-data-par/code/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ta-data-par/code/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ta-data-par/code/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ta-data-par/code/languages', 'stargazers_url': 'https://api.github.com/repos/ta-data-par/code/stargazers', 'contributors_url': 'https://api.github.com/repos/ta-data-par/code/contributors', 'subscribers_url': 'https://api.github.com/repos/ta-data-par/code/subscribers', 'subscription_url': 'https://api.github.com/repos/ta-data-par/code/subscription', 'commits_url': 'https://api.github.com/repos/ta-data-par/code/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ta-data-par/code/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ta-data-par/code/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ta-data-par/code/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ta-data-par/code/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ta-data-par/code/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ta-data-par/code/merges', 'archive_url': 'https://api.github.com/repos/ta-data-par/code/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/ta-data-par/code/downloads', 'issues_url': 'https://api.github.com/repos/ta-data-par/code/issues{/number}', 'pulls_url': 'https://api.github.com/repos/ta-data-par/code/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/ta-data-par/code/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/ta-data-par/code/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/ta-data-par/code/labels{/na ...
#
# 0     7
# 1     2
# 18    1
# 31    1
# Name: forks, dtype: int64

# %%
import json
import requests

response = requests.get('https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/commits')
response.status_code
results = response.json()

#print(results)

import pandas as pd
data = pd.DataFrame(results)
data.head(10)
print(data)
print(data.sha.value_counts().sum())
# Out:
#                                          sha  \
# 0   565f69394722cd0ffda494d2f0cd0716b87fa1de
# 1   6d3072d82c4345a119874e9370cf58a2cb51e74d
# 2   357a827d90c8bd94ebd5e27aa6ee0ed86b8c8f99
# 3   70f432167334041f0d1765f61d604d5308dab160
# 4   82fa690fa8b01b8e45f62511da02c3662e9b1c0e
# 5   3da67677da515bdaf8f2472e95eb76aecdd4103b
# 6   74957ea75e2f11902a8b1163350247abae52d629
# 7   a8f78879a5a2bc5c3d26c6012f9fa611c64995ec
# 8   3c236f81b60220280b6189e170f20cec9b646c95
# 9   a4776d68aa317f5ddaa3b9468c70589721cb30b6
# 10  c44ff7fedb56f6093de4e2b1e3542fe9d7d48da9
# 11  cdd80be28137043896aa652873e3447c449dceda
# 12  9713f83627dd4728c3c7eb3a75cf1406c842a66f
# 13  b6f788d8287c3525203967cdc4603b28c7624729
# 14  7e67b17690c2ddb39990e4237cf44e85913a98a9
# 15  e374e3ba9b9dae342de36bdee8bff6a34511f429
# 16  d1a2fcdc9abbb74640b68b0b38743074640cd72d
# 17  7a8c741941e78bf32dbac4db017377a242def99a
# 18  f7a3821d5f64d8afb01bce14906ea09d0a7b043f
# 19  59360b8078f5deda4db6e311f06dbc544bc41538
# 20  7596e99f9c97e11f187ba4382a34a45bfe4c9a01
# 21  948cf3e29ed18a3cee9eef46681ca3acc81c64c3
# 22  4c49c7332cd904a41dbdc3cb124804ec6b81cfaf
# 23  8d9875d9d3087f66e8a585e2beed1c098874893b
# 24  0b64444c2f5d7ff444baa90fe1309298068a056a
# 25  091c53a8a6bc5ed465b8760c0811d10b9f205c62
# 26  582cd19aeb55a5e9fc09a1e82e64d2e8d71c6984
# 27  83285640b8d701e17fba2b1365fda3bc78aaa27b
# 28  2f550cd2a61640a7039b6d585c1fff1451cc2a55
# 29  0081a622b59b53e6c5092a37cd05b735c90f7113
#
#                                               node_id  \
# 0   C_kwDOGbJx_9oAKDU2NWY2OTM5NDcyMmNkMGZmZGE0OTRk...
# 1   C_kwDOGbJx_9oAKDZkMzA3MmQ4MmM0MzQ1YTExOTg3NGU5...
# 2   C_kwDOGbJx_9oAKDM1N2E4MjdkOTBjOGJkOTRlYmQ1ZTI3...
# 3   C_kwDOGbJx_9oAKDcwZjQzMjE2NzMzNDA0MWYwZDE3NjVm...
# 4   C_kwDOGbJx_9oAKDgyZmE2OTBmYThiMDFiOGU0NWY2MjUx...
# 5   C_kwDOGbJx_9oAKDNkYTY3Njc3ZGE1MTViZGFmOGYyNDcy...
# 6   C_kwDOGbJx_9oAKDc0OTU3ZWE3NWUyZjExOTAyYThiMTE2...
# 7   C_kwDOGbJx_9oAKGE4Zjc4ODc5YTVhMmJjNWMzZDI2YzYw...
# 8   C_kwDOGbJx_9oAKDNjMjM2ZjgxYjYwMjIwMjgwYjYxODll...
# 9   C_kwDOGbJx_9oAKGE0Nzc2ZDY4YWEzMTdmNWRkYWEzYjk0...
# 10  C_kwDOGbJx_9oAKGM0NGZmN2ZlZGI1NmY2MDkzZGU0ZTJi...
# 11  C_kwDOGbJx_9oAKGNkZDgwYmUyODEzNzA0Mzg5NmFhNjUy...
# 12  C_kwDOGbJx_9oAKDk3MTNmODM2MjdkZDQ3MjhjM2M3ZWIz...
# 13  C_kwDOGbJx_9oAKGI2Zjc4OGQ4Mjg3YzM1MjUyMDM5Njdj...
# 14  C_kwDOGbJx_9oAKDdlNjdiMTc2OTBjMmRkYjM5OTkwZTQy...
# 15  C_kwDOGbJx_9oAKGUzNzRlM2JhOWI5ZGFlMzQyZGUzNmJk...
# 16  C_kwDOGbJx_9oAKGQxYTJmY2RjOWFiYmI3NDY0MGI2OGIw...
# 17  C_kwDOGbJx_9oAKDdhOGM3NDE5NDFlNzhiZjMyZGJhYzRk...
# 18  C_kwDOGbJx_9oAKGY3YTM4MjFkNWY2NGQ4YWZiMDFiY2Ux...
# 19  C_kwDOGbJx_9oAKDU5MzYwYjgwNzhmNWRlZGE0ZGI2ZTMx...
# 20  C_kwDOGbJx_9oAKDc1OTZlOTlmOWM5N2UxMWYxODdiYTQz...
# 21  C_kwDOGbJx_9oAKDk0OGNmM2UyOWVkMThhM2NlZTllZWY0...
# 22  C_kwDOGbJx_9oAKDRjNDljNzMzMmNkOTA0YTQxZGJkYzNj...
# 23  C_kwDOGbJx_9oAKDhkOTg3NWQ5ZDMwODdmNjZlOGE1ODVl...
# 24  C_kwDOGbJx_9oAKDBiNjQ0NDRjMmY1ZDdmZjQ0NGJhYTkw...
# 25  C_kwDOGbJx_9oAKDA5MWM1M2E4YTZiYzVlZDQ2NWI4NzYw...
# 26  C_kwDOGbJx_9oAKDU4MmNkMTlhZWI1NWE1ZTlmYzA5YTFl...
# 27  C_kwDOGbJx_9oAKDgzMjg1NjQwYjhkNzAxZTE3ZmJhMmIx...
# 28  C_kwDOGbJx_9oAKDJmNTUwY2QyYTYxNjQwYTcwMzliNmQ1...
# 29  C_kwDOGbJx_9oAKDAwODFhNjIyYjU5YjUzZTZjNTA5MmEz...
#
#                                                commit  \
# 0   {'author': {'name': 'ta-data-par', 'email': '5...
# 1   {'author': {'name': 'ta-data-par', 'email': '5...
# 2   {'author': {'name': 'ta-data-par', 'email': '5...
# 3   {'author': {'name': 'ta-data-par', 'email': '5...
# 4   {'author': {'name': 'ta-data-par', 'email': '5...
# 5   {'author': {'name': 'Kseniia-Ilchenko', 'email...
# 6   {'author': {'name': 'Kseniia-Ilchenko', 'email...
# 7   {'author': {'name': 'ta-data-par', 'email': '5...
# 8   {'author': {'name': 'ta-data-par', 'email': '5...
# 9   {'author': {'name': 'ta-data-par', 'email': '5...
# 10  {'author': {'name': 'ta-data-par', 'email': '5...
# 11  {'author': {'name': 'ta-data-par', 'email': '5...
# 12  {'author': {'name': 'ta-data-par', 'email': '5...
# 13  {'author': {'name': 'ta-data-par', 'email': '5...
# 14  {'author': {'name': 'ta-data-par', 'email': '5...
# 15  {'author': {'name': 'ta-data-par', 'email': '5...
# 16  {'author': {'name': 'ta-data-par', 'email': '5...
# 17  {'author': {'name': 'ta-data-par', 'email': '5...
# 18  {'author': {'name': 'Kseniia-Ilchenko', 'email...
# 19  {'author': {'name': 'Kseniia-Ilchenko', 'email...
# 20  {'author': {'name': 'ta-data-par', 'email': '5...
# 21  {'author': {'name': 'ta-data-par', 'email': '5...
# 22  {'author': {'name': 'ta-data-par', 'email': '5...
# 23  {'author': {'name': 'ta-data-par', 'email': '5...
# 24  {'author': {'name': 'ta-data-par', 'email': '5...
# 25  {'author': {'name': 'ta-data-par', 'email': '5...
# 26  {'author': {'name': 'ta-data-par', 'email': '5...
# 27  {'author': {'name': 'ta-data-par', 'email': '5...
# 28  {'author': {'name': 'ta-data-par', 'email': '5...
# 29  {'author': {'name': 'ta-data-par', 'email': '5...
#
#                                                   url  \
# 0   https://api.github.com/repos/ta-data-par/DAFT_...
# 1   https://api.github.com/repos/ta-data-par/DAFT_...
# 2   https://api.github.com/repos/ta-data-par/DAFT_...
# 3   https://api.github.com/repos/ta-data-par/DAFT_...
# 4   https://api.github.com/repos/ta-data-par/DAFT_...
# 5   https://api.github.com/repos/ta-data-par/DAFT_...
# 6   https://api.github.com/repos/ta-data-par/DAFT_...
# 7   https://api.github.com/repos/ta-data-par/DAFT_...
# 8   https://api.github.com/repos/ta-data-par/DAFT_...
# 9   https://api.github.com/repos/ta-data-par/DAFT_...
# 10  https://api.github.com/repos/ta-data-par/DAFT_...
# 11  https://api.github.com/repos/ta-data-par/DAFT_...
# 12  https://api.github.com/repos/ta-data-par/DAFT_...
# 13  https://api.github.com/repos/ta-data-par/DAFT_...
# 14  https://api.github.com/repos/ta-data-par/DAFT_...
# 15  https://api.github.com/repos/ta-data-par/DAFT_...
# 16  https://api.github.com/repos/ta-data-par/DAFT_...
# 17  https://api.github.com/repos/ta-data-par/DAFT_...
# 18  https://api.github.com/repos/ta-data-par/DAFT_...
# 19  https://api.github.com/repos/ta-data-par/DAFT_...
# 20  https://api.github.com/repos/ta-data-par/DAFT_...
# 21  https://api.github.com/repos/ta-data-par/DAFT_...
# 22  https://api.github.com/repos/ta-data-par/DAFT_...
# 23  https://api.github.com/repos/ta-data-par/DAFT_...
# 24  https://api.github.com/repos/ta-data-par/DAFT_...
# 25  https://api.github.com/repos/ta-data-par/DAFT_...
# 26  https://api.github.com/repos/ta-data-par/DAFT_...
# 27  https://api.github.com/repos/ta-data-par/DAFT_...
# 28  https://api.github.com/repos/ta-data-par/DAFT_...
# 29  https://api.github.com/repos/ta-data-par/DAFT_...
#
#                                              html_url  \
# 0   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 1   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 2   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 3   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 4   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 5   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 6   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 7   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 8   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 9   https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 10  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 11  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 12  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 13  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 14  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 15  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 16  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 17  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 18  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 19  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 20  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 21  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 22  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 23  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 24  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 25  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 26  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 27  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 28  https://github.com/ta-data-par/DAFT_NOV_21_01/...
# 29  https://github.com/ta-data-par/DAFT_NOV_21_01/...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/ta-data-par/DAFT_...
# 1   https://api.github.com/repos/ta-data-par/DAFT_...
# 2   https://api.github.com/repos/ta-data-par/DAFT_...
# 3   https://api.github.com/repos/ta-data-par/DAFT_...
# 4   https://api.github.com/repos/ta-data-par/DAFT_...
# 5   https://api.github.com/repos/ta-data-par/DAFT_...
# 6   https://api.github.com/repos/ta-data-par/DAFT_...
# 7   https://api.github.com/repos/ta-data-par/DAFT_...
# 8   https://api.github.com/repos/ta-data-par/DAFT_...
# 9   https://api.github.com/repos/ta-data-par/DAFT_...
# 10  https://api.github.com/repos/ta-data-par/DAFT_...
# 11  https://api.github.com/repos/ta-data-par/DAFT_...
# 12  https://api.github.com/repos/ta-data-par/DAFT_...
# 13  https://api.github.com/repos/ta-data-par/DAFT_...
# 14  https://api.github.com/repos/ta-data-par/DAFT_...
# 15  https://api.github.com/repos/ta-data-par/DAFT_...
# 16  https://api.github.com/repos/ta-data-par/DAFT_...
# 17  https://api.github.com/repos/ta-data-par/DAFT_...
# 18  https://api.github.com/repos/ta-data-par/DAFT_...
# 19  https://api.github.com/repos/ta-data-par/DAFT_...
# 20  https://api.github.com/repos/ta-data-par/DAFT_...
# 21  https://api.github.com/repos/ta-data-par/DAFT_...
# 22  https://api.github.com/repos/ta-data-par/DAFT_...
# 23  https://api.github.com/repos/ta-data-par/DAFT_...
# 24  https://api.github.com/repos/ta-data-par/DAFT_...
# 25  https://api.github.com/repos/ta-data-par/DAFT_...
# 26  https://api.github.com/repos/ta-data-par/DAFT_...
# 27  https://api.github.com/repos/ta-data-par/DAFT_...
# 28  https://api.github.com/repos/ta-data-par/DAFT_...
# 29  https://api.github.com/repos/ta-data-par/DAFT_...
#
#                                                author  \
# 0   {'login': 'ta-data-par', 'id': 50342645, 'node...
# 1   {'login': 'ta-data-par', 'id': 50342645, 'node...
# 2   {'login': 'ta-data-par', 'id': 50342645, 'node...
# 3   {'login': 'ta-data-par', 'id': 50342645, 'node...
# 4   {'login': 'ta-data-par', 'id': 50342645, 'node...
# 5   {'login': 'Kseniia-Ilchenko', 'id': 94683520, ...
# 6   {'login': 'Kseniia-Ilchenko', 'id': 94683520, ...
# 7   {'login': 'ta-data-par', 'id': 50342645, 'node...
# 8   {'login': 'ta-data-par', 'id': 50342645, 'node...
# 9   {'login': 'ta-data-par', 'id': 50342645, 'node...
# 10  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 11  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 12  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 13  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 14  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 15  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 16  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 17  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 18  {'login': 'Kseniia-Ilchenko', 'id': 94683520, ...
# 19  {'login': 'Kseniia-Ilchenko', 'id': 94683520, ...
# 20  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 21  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 22  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 23  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 24  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 25  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 26  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 27  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 28  {'login': 'ta-data-par', 'id': 50342645, 'node...
# 29  {'login': 'ta-data-par', 'id': 50342645, 'node...
#
#                                             committer  \
# 0   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 1   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 2   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 3   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 4   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 5   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 6   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 7   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 8   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 9   {'login': 'web-flow', 'id': 19864447, 'node_id...
# 10  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 11  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 12  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 13  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 14  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 15  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 16  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 17  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 18  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 19  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 20  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 21  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 22  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 23  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 24  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 25  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 26  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 27  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 28  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 29  {'login': 'web-flow', 'id': 19864447, 'node_id...
#
#                                               parents
# 0   [{'sha': '6d3072d82c4345a119874e9370cf58a2cb51...
# 1   [{'sha': '357a827d90c8bd94ebd5e27aa6ee0ed86b8c...
# 2   [{'sha': '70f432167334041f0d1765f61d604d5308da...
# 3   [{'sha': '82fa690fa8b01b8e45f62511da02c3662e9b...
# 4   [{'sha': 'a8f78879a5a2bc5c3d26c6012f9fa611c649...
# 5   [{'sha': 'a8f78879a5a2bc5c3d26c6012f9fa611c649...
# 6   [{'sha': 'a8f78879a5a2bc5c3d26c6012f9fa611c649...
# 7   [{'sha': '3c236f81b60220280b6189e170f20cec9b64...
# 8   [{'sha': 'a4776d68aa317f5ddaa3b9468c70589721cb...
# 9   [{'sha': 'c44ff7fedb56f6093de4e2b1e3542fe9d7d4...
# 10  [{'sha': 'cdd80be28137043896aa652873e3447c449d...
# 11  [{'sha': '9713f83627dd4728c3c7eb3a75cf1406c842...
# 12  [{'sha': 'b6f788d8287c3525203967cdc4603b28c762...
# 13  [{'sha': '7e67b17690c2ddb39990e4237cf44e85913a...
# 14  [{'sha': 'e374e3ba9b9dae342de36bdee8bff6a34511...
# 15  [{'sha': 'd1a2fcdc9abbb74640b68b0b38743074640c...
# 16  [{'sha': '7a8c741941e78bf32dbac4db017377a242de...
# 17  [{'sha': '7596e99f9c97e11f187ba4382a34a45bfe4c...
# 18  [{'sha': '7596e99f9c97e11f187ba4382a34a45bfe4c...
# 19  [{'sha': '7596e99f9c97e11f187ba4382a34a45bfe4c...
# 20  [{'sha': '948cf3e29ed18a3cee9eef46681ca3acc81c...
# 21  [{'sha': '4c49c7332cd904a41dbdc3cb124804ec6b81...
# 22  [{'sha': '8d9875d9d3087f66e8a585e2beed1c098874...
# 23  [{'sha': '0b64444c2f5d7ff444baa90fe1309298068a...
# 24  [{'sha': '091c53a8a6bc5ed465b8760c0811d10b9f20...
# 25  [{'sha': '582cd19aeb55a5e9fc09a1e82e64d2e8d71c...
# 26  [{'sha': '83285640b8d701e17fba2b1365fda3bc78aa...
# 27  [{'sha': '2f550cd2a61640a7039b6d585c1fff1451cc...
# 28  [{'sha': '0081a622b59b53e6c5092a37cd05b735c90f...
# 29  [{'sha': 'ce36d62d847395fc946b75a1f8cd29a72401...
# 30

# %%
import json
import requests

response = requests.get('https://api.github.com/repos/ta-data-par/DAFT_NOV_21_01/languages')
response.status_code
results = response.json()

print(results)
# Out:
# {'Jupyter Notebook': 2722289, 'Python': 9907}

# %%
import json
import requests

response = requests.get('https://api.github.com/users/ironhack-datalabs/repos')
response.status_code
results = response.json()

print(results)
# Out:
# [{'id': 169605092, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjk2MDUwOTI=', 'name': 'bcn-feb-2019', 'full_name': 'ironhack-datalabs/bcn-feb-2019', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://github.com/ironhack-datalabs', 'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers', 'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}', 'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions', 'organizations_url': 'https://api.github.com/users/ironhack-datalabs/orgs', 'repos_url': 'https://api.github.com/users/ironhack-datalabs/repos', 'events_url': 'https://api.github.com/users/ironhack-datalabs/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ironhack-datalabs/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/ironhack-datalabs/bcn-feb-2019', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019', 'forks_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/forks', 'keys_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/teams', 'hooks_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/hooks', 'issue_events_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/events', 'assignees_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/tags', 'blobs_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/languages', 'stargazers_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/stargazers', 'contributors_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/contributors', 'subscribers_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/subscribers', 'subscription_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/subscription', 'commits_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/contents/{+path}', 'compare_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/ironhack-datalabs/bcn-feb-2019/merges', 'archive_url': 'https://api.github.com/repos/ironhack-datalabs/bcn- ...

# %%
import pandas as pd
data = pd.DataFrame(results)
print(data.head(50))
# Out:
#            id                           node_id                   name  \
# 0   169605092  MDEwOlJlcG9zaXRvcnkxNjk2MDUwOTI=           bcn-feb-2019
# 1   170384482  MDEwOlJlcG9zaXRvcnkxNzAzODQ0ODI=   bcn-feb-2019-prework
# 2   231368458  MDEwOlJlcG9zaXRvcnkyMzEzNjg0NTg=         data-ber-01-20
# 3   244373859  MDEwOlJlcG9zaXRvcnkyNDQzNzM4NTk=         data-ber-03-20
# 4   263332192  MDEwOlJlcG9zaXRvcnkyNjMzMzIxOTI=         data-ber-06-20
# 5   285653289  MDEwOlJlcG9zaXRvcnkyODU2NTMyODk=         data-ber-08-20
# 6   213957020  MDEwOlJlcG9zaXRvcnkyMTM5NTcwMjA=         data-ber-10-19
# 7   289891815  MDEwOlJlcG9zaXRvcnkyODk4OTE4MTU=      data-pt-ber-08-20
# 8   188433440  MDEwOlJlcG9zaXRvcnkxODg0MzM0NDA=         databcn0519-pt
# 9   188459756  MDEwOlJlcG9zaXRvcnkxODg0NTk3NTY=            databer0619
# 10  196546532  MDEwOlJlcG9zaXRvcnkxOTY1NDY1MzI=  databer0619-solutions
# 11  198647222  MDEwOlJlcG9zaXRvcnkxOTg2NDcyMjI=            datalis0819
# 12  167007163  MDEwOlJlcG9zaXRvcnkxNjcwMDcxNjM=            datamad0119
# 13  233579456  MDEwOlJlcG9zaXRvcnkyMzM1Nzk0NTY=            datamad0120
# 14  249412666  MDEwOlJlcG9zaXRvcnkyNDk0MTI2NjY=            datamad0320
# 15  180311907  MDEwOlJlcG9zaXRvcnkxODAzMTE5MDc=            datamad0419
# 16  182146628  MDEwOlJlcG9zaXRvcnkxODIxNDY2Mjg=         datamad0419-pt
# 17  191172852  MDEwOlJlcG9zaXRvcnkxOTExNzI4NTI=            datamad0619
# 18  268509421  MDEwOlJlcG9zaXRvcnkyNjg1MDk0MjE=            datamad0620
# 19  203385262  MDEwOlJlcG9zaXRvcnkyMDMzODUyNjI=            datamad0819
# 20  288154375  MDEwOlJlcG9zaXRvcnkyODgxNTQzNzU=            datamad0820
# 21  216576443  MDEwOlJlcG9zaXRvcnkyMTY1NzY0NDM=            datamad1019
# 22  303186331  MDEwOlJlcG9zaXRvcnkzMDMxODYzMzE=            datamad1020
# 23  304248539  MDEwOlJlcG9zaXRvcnkzMDQyNDg1Mzk=        datamad1020-rev
# 24  232141175  MDEwOlJlcG9zaXRvcnkyMzIxNDExNzU=            datamex0120
# 25  248539312  MDEwOlJlcG9zaXRvcnkyNDg1MzkzMTI=            datamex0320
# 26  216407244  MDEwOlJlcG9zaXRvcnkyMTY0MDcyNDQ=            datamex1019
# 27  191081936  MDEwOlJlcG9zaXRvcnkxOTEwODE5MzY=            datamia0619
# 28  200671108  MDEwOlJlcG9zaXRvcnkyMDA2NzExMDg=            datamia0819
# 29  216472171  MDEwOlJlcG9zaXRvcnkyMTY0NzIxNzE=            datamia1019
#
#                                   full_name  private  \
# 0            ironhack-datalabs/bcn-feb-2019    False
# 1    ironhack-datalabs/bcn-feb-2019-prework    False
# 2          ironhack-datalabs/data-ber-01-20    False
# 3          ironhack-datalabs/data-ber-03-20    False
# 4          ironhack-datalabs/data-ber-06-20    False
# 5          ironhack-datalabs/data-ber-08-20    False
# 6          ironhack-datalabs/data-ber-10-19    False
# 7       ironhack-datalabs/data-pt-ber-08-20    False
# 8          ironhack-datalabs/databcn0519-pt    False
# 9             ironhack-datalabs/databer0619    False
# 10  ironhack-datalabs/databer0619-solutions    False
# 11            ironhack-datalabs/datalis0819    False
# 12            ironhack-datalabs/datamad0119    False
# 13            ironhack-datalabs/datamad0120    False
# 14            ironhack-datalabs/datamad0320    False
# 15            ironhack-datalabs/datamad0419    False
# 16         ironhack-datalabs/datamad0419-pt    False
# 17            ironhack-datalabs/datamad0619    False
# 18            ironhack-datalabs/datamad0620    False
# 19            ironhack-datalabs/datamad0819    False
# 20            ironhack-datalabs/datamad0820    False
# 21            ironhack-datalabs/datamad1019    False
# 22            ironhack-datalabs/datamad1020    False
# 23        ironhack-datalabs/datamad1020-rev    False
# 24            ironhack-datalabs/datamex0120    False
# 25            ironhack-datalabs/datamex0320    False
# 26            ironhack-datalabs/datamex1019    False
# 27            ironhack-datalabs/datamia0619    False
# 28            ironhack-datalabs/datamia0819    False
# 29            ironhack-datalabs/datamia1019    False
#
#                                                 owner  \
# 0   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 1   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 2   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 3   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 4   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 5   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 6   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 7   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 8   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 9   {'login': 'ironhack-datalabs', 'id': 44225188,...
# 10  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 11  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 12  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 13  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 14  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 15  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 16  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 17  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 18  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 19  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 20  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 21  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 22  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 23  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 24  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 25  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 26  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 27  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 28  {'login': 'ironhack-datalabs', 'id': 44225188,...
# 29  {'login': 'ironhack-datalabs', 'id': 44225188,...
#
#                                              html_url  \
# 0   https://github.com/ironhack-datalabs/bcn-feb-2019
# 1   https://github.com/ironhack-datalabs/bcn-feb-2...
# 2   https://github.com/ironhack-datalabs/data-ber-...
# 3   https://github.com/ironhack-datalabs/data-ber-...
# 4   https://github.com/ironhack-datalabs/data-ber-...
# 5   https://github.com/ironhack-datalabs/data-ber-...
# 6   https://github.com/ironhack-datalabs/data-ber-...
# 7   https://github.com/ironhack-datalabs/data-pt-b...
# 8   https://github.com/ironhack-datalabs/databcn05...
# 9    https://github.com/ironhack-datalabs/databer0619
# 10  https://github.com/ironhack-datalabs/databer06...
# 11   https://github.com/ironhack-datalabs/datalis0819
# 12   https://github.com/ironhack-datalabs/datamad0119
# 13   https://github.com/ironhack-datalabs/datamad0120
# 14   https://github.com/ironhack-datalabs/datamad0320
# 15   https://github.com/ironhack-datalabs/datamad0419
# 16  https://github.com/ironhack-datalabs/datamad04...
# 17   https://github.com/ironhack-datalabs/datamad0619
# 18   https://github.com/ironhack-datalabs/datamad0620
# 19   https://github.com/ironhack-datalabs/datamad0819
# 20   https://github.com/ironhack-datalabs/datamad0820
# 21   https://github.com/ironhack-datalabs/datamad1019
# 22   https://github.com/ironhack-datalabs/datamad1020
# 23  https://github.com/ironhack-datalabs/datamad10...
# 24   https://github.com/ironhack-datalabs/datamex0120
# 25   https://github.com/ironhack-datalabs/datamex0320
# 26   https://github.com/ironhack-datalabs/datamex1019
# 27   https://github.com/ironhack-datalabs/datamia0619
# 28   https://github.com/ironhack-datalabs/datamia0819
# 29   https://github.com/ironhack-datalabs/datamia1019
#
#                                           description   fork  \
# 0                                                None  False
# 1                                                None  False
# 2   Main Official Data Labs for the Jan 2020 Berli...  False
# 3   Main Official Data Labs for the March 2020 Ber...  False
# 4   Main Official Data Labs for the June 2020 Berl...  False
# 5   Main Official Data Labs for the August 2020 Be...  False
# 6                                                None  False
# 7   Main Official Data Labs for the August 2020 Be...  False
# 8                                                None  False
# 9                                                None  False
# 10                                               None  False
# 11       Data Analytics Full Time Lisbon, August 2019  False
# 12                                               None  False
# 13                                               None  False
# 14                                               None  False
# 15                                               None  False
# 16                                               None  False
# 17  Labs and exercises for Ironhack Madrid Data Bo...  False
# 18                                               None  False
# 19                                               None  False
# 20                                               None  False
# 21                                               None  False
# 22  exercises for datamad1020 bootcamp @ Ironhack ...  False
# 23                                               None  False
# 24                                               None  False
# 25                     Data Analytics Bootcamp Mexico  False
# 26                                               None  False
# 27           Data Analytics Full Time Miami June 2019  False
# 28         Data Analytics Full Time Miami August 2019  False
# 29                                               None  False
#
#                                                   url  ... open_issues_count  \
# 0   https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 1   https://api.github.com/repos/ironhack-datalabs...  ...               402
# 2   https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 3   https://api.github.com/repos/ironhack-datalabs...  ...                 1
# 4   https://api.github.com/repos/ironhack-datalabs...  ...                 1
# 5   https://api.github.com/repos/ironhack-datalabs...  ...                 2
# 6   https://api.github.com/repos/ironhack-datalabs...  ...                 4
# 7   https://api.github.com/repos/ironhack-datalabs...  ...                 2
# 8   https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 9   https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 10  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 11  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 12  https://api.github.com/repos/ironhack-datalabs...  ...                 9
# 13  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 14  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 15  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 16  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 17  https://api.github.com/repos/ironhack-datalabs...  ...                 7
# 18  https://api.github.com/repos/ironhack-datalabs...  ...                 2
# 19  https://api.github.com/repos/ironhack-datalabs...  ...                 6
# 20  https://api.github.com/repos/ironhack-datalabs...  ...               137
# 21  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 22  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 23  https://api.github.com/repos/ironhack-datalabs...  ...                 0
# 24  https://api.github.com/repos/ironhack-datalabs...  ...                 2
# 25  https://api.github.com/repos/ironhack-datalabs...  ...                22
# 26  https://api.github.com/repos/ironhack-datalabs...  ...                14
# 27  https://api.github.com/repos/ironhack-datalabs...  ...               133
# 28  https://api.github.com/repos/ironhack-datalabs...  ...                28
# 29  https://api.github.com/repos/ironhack-datalabs...  ...                 0
#
#                                               license allow_forking  \
# 0   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 1   {'key': 'unlicense', 'name': 'The Unlicense', ...          True
# 2   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 3   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 4   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 5   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 6   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 7   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 8   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 9   {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 10                                               None          True
# 11  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 12  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 13  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 14  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 15  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 16  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 17  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 18  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 19  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 20  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 21  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 22  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 23  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 24  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 25  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 26  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 27  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 28  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 29  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
#
#    is_template topics visibility forks open_issues watchers default_branch
# 0        False     []     public     6           0        0         master
# 1        False     []     public   501         402        4         master
# 2        False     []     public     8           0        0         master
# 3        False     []     public    18           1        0         master
# 4        False     []     public    19           1        3         master
# 5        False     []     public    23           2        4         master
# 6        False     []     public    16           4        1         master
# 7        False     []     public    32           2        1         master
# 8        False     []     public     1           0        0         master
# 9        False     []     public     8           0        1         master
# 10       False     []     public     1           0        1         master
# 11       False     []     public    12           0        1         master
# 12       False     []     public    17           9        1         master
# 13       False     []     public    30           0        3         master
# 14       False     []     public    24           0        0         master
# 15       False     []     public    20           0        1         master
# 16       False     []     public     0           0        0         master
# 17       False     []     public    24           7        2         master
# 18       False     []     public    24           2        0         master
# 19       False     []     public    22           6        1         master
# 20       False     []     public    28         137        0         master
# 21       False     []     public    32           0        3         master
# 22       False     []     public    20           0        1         master
# 23       False     []     public    25           0        1         master
# 24       False     []     public    15           2        2         master
# 25       False     []     public    17          22        0         master
# 26       False     []     public    36          14        1         master
# 27       False     []     public     7         133        3         master
# 28       False     []     public     7          28        0         master
# 29       False     []     public     5           0        0         master
#
# [30 rows x 77 columns]

# %%
import json
import requests

response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/actions/secrets/scavengerhunt')
response.status_code
results = response.json()

print(results)
# Out:
# {'message': 'Must have admin rights to Repository.', 'documentation_url': 'https://docs.github.com/rest/reference/actions#get-a-repository-secret'}

# %%
import json
import requests

response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
response.status_code
results = response.json()

print(results)
# Out:
# {'total_count': 24, 'incomplete_results': False, 'items': [{'name': '.0016.scavengerhunt', 'path': '47222/.0016.scavengerhunt', 'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0', 'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', 'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt', 'repository': {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=', 'name': 'scavenger', 'full_name': 'ironhack-datalabs/scavenger', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://github.com/ironhack-datalabs', 'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers', 'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}', 'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions', 'organizations_url': 'https://api.github.com/users/ironhack-datalabs/orgs', 'repos_url': 'https://api.github.com/users/ironhack-datalabs/repos', 'events_url': 'https://api.github.com/users/ironhack-datalabs/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ironhack-datalabs/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/ironhack-datalabs/scavenger', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger', 'forks_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/forks', 'keys_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/teams', 'hooks_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/hooks', 'issue_events_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/events', 'assignees_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/tags', 'blobs_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/languages', 'stargazers_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/stargazers', 'contributors_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contributors', 'subscribers_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/subscribers', 'subscription_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/subscription', 'commits_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ironhack-datal ...

# %%
import pandas as pd
data = pd.DataFrame(results)
print(data.head(50))
#print(data)
# Out:
#     total_count  incomplete_results  \
# 0            24               False
# 1            24               False
# 2            24               False
# 3            24               False
# 4            24               False
# 5            24               False
# 6            24               False
# 7            24               False
# 8            24               False
# 9            24               False
# 10           24               False
# 11           24               False
# 12           24               False
# 13           24               False
# 14           24               False
# 15           24               False
# 16           24               False
# 17           24               False
# 18           24               False
# 19           24               False
# 20           24               False
# 21           24               False
# 22           24               False
# 23           24               False
#
#                                                 items
# 0   {'name': '.0016.scavengerhunt', 'path': '47222...
# 1   {'name': '.0009.scavengerhunt', 'path': '97881...
# 2   {'name': '.0021.scavengerhunt', 'path': '30351...
# 3   {'name': '.0023.scavengerhunt', 'path': '55417...
# 4   {'name': '.0019.scavengerhunt', 'path': '70751...
# 5   {'name': '.0002.scavengerhunt', 'path': '88596...
# 6   {'name': '.0011.scavengerhunt', 'path': '50896...
# 7   {'name': '.0006.scavengerhunt', 'path': '15024...
# 8   {'name': '.0014.scavengerhunt', 'path': '49418...
# 9   {'name': '.0012.scavengerhunt', 'path': '15534...
# 10  {'name': '.0001.scavengerhunt', 'path': '98750...
# 11  {'name': '.0018.scavengerhunt', 'path': '45525...
# 12  {'name': '.0013.scavengerhunt', 'path': '89338...
# 13  {'name': '.0005.scavengerhunt', 'path': '44639...
# 14  {'name': '.0020.scavengerhunt', 'path': '55685...
# 15  {'name': '.0024.scavengerhunt', 'path': '47222...
# 16  {'name': '.0015.scavengerhunt', 'path': '91701...
# 17  {'name': '.0007.scavengerhunt', 'path': '17020...
# 18  {'name': '.0003.scavengerhunt', 'path': '60224...
# 19  {'name': '.0022.scavengerhunt', 'path': '40303...
# 20  {'name': '.0010.scavengerhunt', 'path': '47830...
# 21  {'name': '.0004.scavengerhunt', 'path': '68848...
# 22  {'name': '.0017.scavengerhunt', 'path': '70985...
# 23  {'name': '.0008.scavengerhunt', 'path': '15534...

# %%
def flatten(data, col_list):
     for column in col_list:
         flattened = pd.DataFrame(dict(data[column])).transpose()
         columns = [str(col) for col in flattened.columns]
         flattened.columns = [column + '_' + colname for colname in columns]
         data = pd.concat([data, flattened], axis=1)
         data = data.drop(column, axis=1)
     return data

nested_columns = ['total_count','incomplete_results','items', 'path']
flat = flatten(data, nested_columns)


print(data.sort_values('items', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-5cb2e7dd7045> in <module>
#       9
#      10 nested_columns = ['total_count','incomplete_results','items', 'path']
# ---> 11 flat = flatten(data, nested_columns)
#      12
#      13 #print(data.sort_values('items', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None))
#
# <ipython-input-136-5cb2e7dd7045> in flatten(data, col_list)
#       1 def flatten(data, col_list):
#       2      for column in col_list:
# ----> 3          flattened = pd.DataFrame(dict(data[column])).transpose()
#       4          columns = [str(col) for col in flattened.columns]
#       5          flattened.columns = [column + '_' + colname for colname in columns]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     389
#     390         if not indexes and not raw_lengths:
# --> 391             raise ValueError("If using all scalar values, you must pass an index")
#     392
#     393         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
items=results['items']

# %%
# Out:
# [{'name': '.0016.scavengerhunt', 'path': '47222/.0016.scavengerhunt', 'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0', 'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', 'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt', 'repository': {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=', 'name': 'scavenger', 'full_name': 'ironhack-datalabs/scavenger', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://github.com/ironhack-datalabs', 'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers', 'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}', 'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions', 'organizations_url': 'https://api.github.com/users/ironhack-datalabs/orgs', 'repos_url': 'https://api.github.com/users/ironhack-datalabs/repos', 'events_url': 'https://api.github.com/users/ironhack-datalabs/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ironhack-datalabs/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/ironhack-datalabs/scavenger', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger', 'forks_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/forks', 'keys_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/teams', 'hooks_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/hooks', 'issue_events_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/events', 'assignees_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/tags', 'blobs_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/languages', 'stargazers_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/stargazers', 'contributors_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contributors', 'subscribers_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/subscribers', 'subscription_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/subscription', 'commits_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/comments{/number}', 'issue_comment_url': 'ht ...
