# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
table=pd.read_csv(r"C:\Users\Michel\git2\LabsDataAnalyticsIronhack\module_1\Lab_29_1 Pandas+\Admission_Predict.csv")
table
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 380         381        324          110                  3  3.5   3.5  9.04
# 381         382        325          107                  3  3.0   3.5  9.11
# 382         383        330          116                  4  5.0   4.5  9.45
# 383         384        312          103                  3  3.5   4.0  8.78
# 384         385        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# your code here
table.columns = [column.strip(' ') for column in table.columns]
table.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
table.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
table.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
table.set_index('Serial No.', inplace=True)

# %%
table.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
table['GRE-CGPA']= table['GRE Score'].apply(str) + '-' + table['CGPA'].apply(str)
table.head(5)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit  GRE-CGPA
# Serial No.
# 1                  1             0.92  337-9.65
# 2                  1             0.72   316-8.0
# 3                  1             0.80  322-8.67
# 4                  0             0.65  314-8.21
# 5                  1             0.90  330-9.34

# %%
table['GRE-CGPA'].value_counts()
# Out:
# 337-9.65    1
# 334-9.87    1
# 329-9.45    1
# 322-8.96    1
# 315-7.95    1
#            ..
# 303-8.65    1
# 339-9.76    1
# 333-9.35    1
# 326-9.1     1
# 333-9.66    1
# Name: GRE-CGPA, Length: 385, dtype: int64

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
table.set_index('GRE-CGPA', inplace=True)

# %%
table.head(5)
# Out:
#           GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# GRE-CGPA
# 337-9.65        337          118                  4  4.5  4.5  9.65         1
# 316-8.0         316          104                  3  3.0  3.5  8.00         1
# 322-8.67        322          110                  3  3.5  2.5  8.67         1
# 314-8.21        314          103                  2  2.0  3.0  8.21         0
# 330-9.34        330          115                  5  4.5  3.0  9.34         1
#
#           Chance of Admit
# GRE-CGPA
# 337-9.65             0.92
# 316-8.0              0.72
# 322-8.67             0.80
# 314-8.21             0.65
# 330-9.34             0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
table.head()
# Out:
#           GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# GRE-CGPA
# 337-9.65        337          118                  4  4.5  4.5  9.65         1
# 316-8.0         316          104                  3  3.0  3.5  8.00         1
# 322-8.67        322          110                  3  3.5  2.5  8.67         1
# 314-8.21        314          103                  2  2.0  3.0  8.21         0
# 330-9.34        330          115                  5  4.5  3.0  9.34         1
#
#           Chance of Admit
# GRE-CGPA
# 337-9.65             0.92
# 316-8.0              0.72
# 322-8.67             0.80
# 314-8.21             0.65
# 330-9.34             0.90

# %%
filtered = table[(table['CGPA']>=9) &  (table['Research']==1)]

# %%
filtered.head()
# Out:
#           GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# GRE-CGPA
# 337-9.65        337          118                  4  4.5  4.5  9.65         1
# 330-9.34        330          115                  5  4.5  3.0  9.34         1
# 327-9.0         327          111                  4  4.0  4.5  9.00         1
# 328-9.1         328          112                  4  4.0  4.5  9.10         1
# 328-9.5         328          116                  5  5.0  5.0  9.50         1
#
#           Chance of Admit
# GRE-CGPA
# 337-9.65             0.92
# 330-9.34             0.90
# 327-9.0              0.84
# 328-9.1              0.78
# 328-9.5              0.94

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
filtered_2 = table[(table['CGPA']>=9) &  (table['SOP']<=3.5)]
filtered_2.head()
# Out:
#           GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# GRE-CGPA
# 338-9.4         338          118                  4  3.0  4.5  9.40         1
# 327-9.02        327          114                  3  3.0  3.0  9.02         0
# 318-9.22        318          109                  3  3.5  4.0  9.22         1
# 326-9.05        326          112                  3  3.5  3.0  9.05         1
# 338-9.46        338          117                  4  3.5  4.5  9.46         1
#
#           Chance of Admit
# GRE-CGPA
# 338-9.4              0.91
# 327-9.02             0.61
# 318-9.22             0.68
# 326-9.05             0.74
# 338-9.46             0.91

# %%
filtered_2.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
filtered_2['Chance of Admit'].mean()
# Out:
# 0.7975000000000001

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    
    colum = (col - col.mean())/col.std()
    return colum

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
table['CGPA_std']= standardize(table['CGPA'])
table.head(5)
# Out:
#           GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# GRE-CGPA
# 337-9.65        337          118                  4  4.5  4.5  9.65         1
# 316-8.0         316          104                  3  3.0  3.5  8.00         1
# 322-8.67        322          110                  3  3.5  2.5  8.67         1
# 314-8.21        314          103                  2  2.0  3.0  8.21         0
# 330-9.34        330          115                  5  4.5  3.0  9.34         1
#
#           Chance of Admit  CGPA_std
# GRE-CGPA
# 337-9.65             0.92  1.747900
# 316-8.0              0.72 -0.991211
# 322-8.67             0.80  0.121034
# 314-8.21             0.65 -0.642597
# 330-9.34             0.90  1.233279

# %%
table['GRE_std']= standardize(table['GRE Score'])
table['LOR_std']= standardize(table['LOR'])

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

table['decision_choice'] = choices(std_columns, k=table.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
table['decision_value']= table.lookup(table.index, table['decision_choice'])
# Out:
# C:\Users\Michel\AppData\Local\Temp/ipykernel_17836/3187288299.py:1: FutureWarning: The 'lookup' method is deprecated and will beremoved in a future version.You can use DataFrame.melt and DataFrame.locas a substitute.
#   table['decision_value']= table.lookup(table.index, table['decision_choice'])

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
table.lookup(table.index,table['decision_choice'])
# Out:
# C:\Users\Michel\AppData\Local\Temp/ipykernel_17836/2788210562.py:1: FutureWarning: The 'lookup' method is deprecated and will beremoved in a future version.You can use DataFrame.melt and DataFrame.locas a substitute.
#   table.lookup(table.index,table['decision_choice'])
# array([ 1.75338101, -0.0633671 , -1.03816607, -0.48071288, -0.48071288,
#         0.36919198, -0.75546161, -1.2745325 ,  0.54221561,  1.19164669,
#         1.19164669, -0.84197343, -0.49592617, -0.49319082,  0.02314472,
#        -0.48071288, -0.48071288, -0.16117741, -0.32718412,  1.49888959,
#         1.49384557,  1.6668692 ,  0.45570379, -1.03816607, -1.8801152 ,
#        -1.59561926, -0.82520422,  0.88826287,  1.19164669,  1.66489629,
#         1.74909988,  1.00086949, -0.32718412, -1.59561926, -1.10150887,
#         0.07674031, -0.75546161, -0.0633671 , -1.59561926,  0.83486279,
#         1.33288289,  0.83486279,  1.74909988,  1.83090299,  1.74909988,
# ...

# %%
# your code here
table['Admit']=np.where(table['decision_value'] > 0.8, 1, 0)
table.head()
# Out:
#           GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# GRE-CGPA
# 337-9.65        337          118                  4  4.5  4.5  9.65         1
# 316-8.0         316          104                  3  3.0  3.5  8.00         1
# 322-8.67        322          110                  3  3.5  2.5  8.67         1
# 314-8.21        314          103                  2  2.0  3.0  8.21         0
# 330-9.34        330          115                  5  4.5  3.0  9.34         1
#
#           Chance of Admit  CGPA_std   GRE_std   LOR_std decision_choice  \
# GRE-CGPA
# 337-9.65             0.92  1.747900  1.753381  1.191647         GRE_std
# 316-8.0              0.72 -0.991211 -0.063367  0.076740         GRE_std
# 322-8.67             0.80  0.121034  0.455704 -1.038166         LOR_std
# 314-8.21             0.65 -0.642597 -0.236391 -0.480713         LOR_std
# 330-9.34             0.90  1.233279  1.147798 -0.480713         LOR_std
#
#           decision_value  Admit
# ...

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
table.Admit.value_counts()
# Out:
# 0    292
# 1     93
# Name: Admit, dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
cols=list(table.columns)

# %%
table.columns = [col.replace(' ','_').lower().replace('[#,@,&,.]', '') for col in cols]
table.columns
# Out:
# Index(['gre_score', 'toefl_score', 'university_rating', 'sop', 'lor', 'cgpa',
#        'research', 'chance_of_admit', 'cgpa_std', 'gre_std', 'lor_std',
#        'decision_choice', 'decision_value', 'admit'],
#       dtype='object')

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
table['adjusted_gre']=np.where(table['university_rating'] > 4, table['gre_score']+10, table['gre_score'])

# %%
table.head(2)
# Out:
#           gre_score  toefl_score  university_rating  sop  lor  cgpa  research  \
# GRE-CGPA
# 337-9.65        337          118                  4  4.5  4.5  9.65         1
# 316-8.0         316          104                  3  3.0  3.5  8.00         1
#
#           chance_of_admit  cgpa_std   gre_std   lor_std decision_choice  \
# GRE-CGPA
# 337-9.65             0.92  1.747900  1.753381  1.191647         GRE_std
# 316-8.0              0.72 -0.991211 -0.063367  0.076740         GRE_std
#
#           decision_value  admit  adjusted_gre
# GRE-CGPA
# 337-9.65        1.753381      1           337
# 316-8.0        -0.063367      0           316

# %%
gre_labels = ['bad', 'medium', 'good','very good']
adjusted_gre_bins = pd.cut(table['adjusted_gre'],4, labels=gre_labels)

# %%
adjusted_gre_bins
# Out:
# GRE-CGPA
# 337-9.65    very good
# 316-8.0        medium
# 322-8.67         good
# 314-8.21       medium
# 330-9.34    very good
#               ...
# 324-9.04         good
# 325-9.11         good
# 330-9.45         good
# 312-8.78       medium
# 333-9.66         good
# Name: adjusted_gre, Length: 385, dtype: category
# Categories (4, object): ['bad' < 'medium' < 'good' < 'very good']
